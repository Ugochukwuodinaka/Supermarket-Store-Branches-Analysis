# %% [markdown]
# ### EXPLORATORY DATA ANALYSIS ON SUPERMARKET STORE BRANCHES' SALES DATASET

# %% [markdown]
# ### EXPLORATORY DATA ANALYSIS STEPS
# - Importing the required Libraries for EDA
# - Acquiring the dataset
# - Data Preparation
# - Data Profiling
# - Data Cleaning
#     1. Dropping Duplicates
#     2. Removing Missing Values
# - Finding Outliers
# - Finding Correlations
# - Visualizations

# %%
# Importing the required Libraries for EDA
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.express as px

# %%
df = pd.DataFrame()

# %%
# Acquire the dataset
df = pd.read_csv(r"stores.csv")

# %%
df
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0            1        1659             1961                   530        66490
# 1            2        1461             1752                   210        39820
# 2            3        1340             1609                   720        54010
# 3            4        1451             1748                   620        53730
# 4            5        1770             2111                   450        46620
# ..         ...         ...              ...                   ...          ...
# 891        892        1582             1910                  1080        66390
# 892        893        1387             1663                   850        82080
# 893        894        1200             1436                  1060        76440
# 894        895        1299             1560                   770        96610
# 895        896        1174             1429                  1110        54340
#
# [896 rows x 5 columns]

# %%
# first 10 rows of data
df.head(10)
# Out:
#    Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0          1        1659             1961                   530        66490
# 1          2        1461             1752                   210        39820
# 2          3        1340             1609                   720        54010
# 3          4        1451             1748                   620        53730
# 4          5        1770             2111                   450        46620
# 5          6        1442             1733                   760        45260
# 6          7        1542             1858                  1030        72240
# 7          8        1261             1507                  1020        37720
# 8          9        1090             1321                   680        46310
# 9         10        1030             1235                  1130        44150

# %%
# last 10 rows of data
df.tail(10)
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 886        887        1655             1986                  1150        77430
# 887        888        1156             1398                   140        92370
# 888        889        1451             1734                   670        34880
# 889        890        1539             1829                   650        46580
# 890        891        1549             1851                  1220        70620
# 891        892        1582             1910                  1080        66390
# 892        893        1387             1663                   850        82080
# 893        894        1200             1436                  1060        76440
# 894        895        1299             1560                   770        96610
# 895        896        1174             1429                  1110        54340

# %% [markdown]
# ### DATA PROFILING STEPS
# - **Data profiling utilizes methods of descriptive statistics such as:**
#
#       1. Data type
#       2. Quantile statistics (central tendecies)
#       3. Length (length and shape of the dataset)
#       4. Discrete values
#       5. Uniqueness (unique values)
#       6. Occurence of null values and etc.

# %%
# shape of the data
df.shape
# Out:
# (896, 5)

# %%
# size of the data
df.size
# Out:
# 4480

# %%
# check the columns
df.columns
# Out:
# Index(['Store ID ', 'Store_Area', 'Items_Available', 'Daily_Customer_Count',
#        'Store_Sales'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['Store ID ',
#  'Store_Area',
#  'Items_Available',
#  'Daily_Customer_Count',
#  'Store_Sales']

# %%
# check the data types
df.dtypes
# Out:
# Store ID                int64
# Store_Area              int64
# Items_Available         int64
# Daily_Customer_Count    int64
# Store_Sales             int64
# dtype: object

# %%
# check the data information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 896 entries, 0 to 895
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Store ID              896 non-null    int64
#  1   Store_Area            896 non-null    int64
#  2   Items_Available       896 non-null    int64
#  3   Daily_Customer_Count  896 non-null    int64
#  4   Store_Sales           896 non-null    int64
# dtypes: int64(5)
# memory usage: 35.1 KB

# %%
# Data Profiling
# check the descriptive statistics
df.describe()
# Out:
#         Store ID    Store_Area  Items_Available  Daily_Customer_Count  \
# count  896.000000   896.000000       896.000000            896.000000
# mean   448.500000  1485.409598      1782.035714            786.350446
# std    258.797218   250.237011       299.872053            265.389281
# min      1.000000   775.000000       932.000000             10.000000
# 25%    224.750000  1316.750000      1575.500000            600.000000
# 50%    448.500000  1477.000000      1773.500000            780.000000
# 75%    672.250000  1653.500000      1982.750000            970.000000
# max    896.000000  2229.000000      2667.000000           1560.000000
#
#          Store_Sales
# count     896.000000
# mean    59351.305804
# std     17190.741895
# min     14920.000000
# 25%     46530.000000
# 50%     58605.000000
# 75%     71872.500000
# max    116320.000000

# %%
df.describe().astype(int)
# Out:
#        Store ID   Store_Area  Items_Available  Daily_Customer_Count  \
# count        896         896              896                   896
# mean         448        1485             1782                   786
# std          258         250              299                   265
# min            1         775              932                    10
# 25%          224        1316             1575                   600
# 50%          448        1477             1773                   780
# 75%          672        1653             1982                   970
# max          896        2229             2667                  1560
#
#        Store_Sales
# count          896
# mean         59351
# std          17190
# min          14920
# 25%          46530
# 50%          58605
# 75%          71872
# max         116320

# %%
# Check for missing values
# The below doesn't give me explicit description of the null details
df.isnull()
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0        False       False            False                 False        False
# 1        False       False            False                 False        False
# 2        False       False            False                 False        False
# 3        False       False            False                 False        False
# 4        False       False            False                 False        False
# ..         ...         ...              ...                   ...          ...
# 891      False       False            False                 False        False
# 892      False       False            False                 False        False
# 893      False       False            False                 False        False
# 894      False       False            False                 False        False
# 895      False       False            False                 False        False
#
# [896 rows x 5 columns]

# %%
# The below is better explicit
df.isnull().sum()
# Out:
# Store ID                0
# Store_Area              0
# Items_Available         0
# Daily_Customer_Count    0
# Store_Sales             0
# dtype: int64

# %%
# check for negative values in Quantity
df[df[['Store_Area', 'Items_Available', 'Daily_Customer_Count', 'Store_Sales']]< 0]
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0          NaN         NaN              NaN                   NaN          NaN
# 1          NaN         NaN              NaN                   NaN          NaN
# 2          NaN         NaN              NaN                   NaN          NaN
# 3          NaN         NaN              NaN                   NaN          NaN
# 4          NaN         NaN              NaN                   NaN          NaN
# ..         ...         ...              ...                   ...          ...
# 891        NaN         NaN              NaN                   NaN          NaN
# 892        NaN         NaN              NaN                   NaN          NaN
# 893        NaN         NaN              NaN                   NaN          NaN
# 894        NaN         NaN              NaN                   NaN          NaN
# 895        NaN         NaN              NaN                   NaN          NaN
#
# [896 rows x 5 columns]

# %% [markdown]
# ### FURTHER ANALYSIS, OBSERVATIONS AND VISUALIZATION

# %%
# Total Sales Valuation from all Supermarket Store Branches
sales_sum = df['Store_Sales'].sum()
new_sales = '${:,.0f}.M'.format(sales_sum)
new_sales
# Out:
# '$53,178,770.M'

# %%
# Rename 'Store ID' to 'Store_ID' for easy data exploration
df.rename(columns={'Store ID ' : 'Store_ID'}, inplace= True)

# %%
df.columns
# Out:
# Index(['Store_ID', 'Store_Area', 'Items_Available', 'Daily_Customer_Count',
#        'Store_Sales'],
#       dtype='object')

# %%
# Total Number of Supermarket Store Branches
stores = df['Store_ID'].count()
stores
# Out:
# 896

# %%
# Total Number of items available in all Supermarket Store Branches
stores_items = df['Items_Available'].sum()
new_storesitems = '{:,.0f}'.format(stores_items)
new_storesitems
# Out:
# '1,596,704'

# %%
# Total Number of customers who visited stores on average over a month
customer_count = df['Daily_Customer_Count'].sum()
new_customercount = '{:,.0f}'.format(customer_count)
new_customercount
# Out:
# '704,570'

# %%
# Total Sales Valuation from all Supermarket Store Branches
sales_sum = df['Store_Sales'].sum()
new_sales = '${:,.0f}.M'.format(sales_sum)
new_sales
# Total Number of Supermarket Store Branches
stores = df['Store_ID'].count()
stores
# Total Number of items available in all Supermarket Store Branches
stores_items = df['Items_Available'].sum()
new_storesitems = '{:,.0f}'.format(stores_items)
new_storesitems
# Total Number of customers who visited stores on average over a month
customer_count = df['Daily_Customer_Count'].sum()
new_customercount = '{:,.0f}'.format(customer_count)
new_customercount


# Print Functions
print('The Total Sales Valuation of Supermarket Store Branches is: ', new_sales)
print('The Total No. of Supermarket Store Branches is: ', stores)
print('The Total No. of Items Available In Supermarket Store Branches is: ', new_storesitems)
print('The Total No. of customers who visited stores on average over a month: ', new_customercount)
# Out:
# The Total Sales Valuation of Supermarket Store Branches is:  $53,178,770.M
# The Total No. of Supermarket Store Branches is:  896
# The Total No. of Items Available In Supermarket Store Branches is:  1,596,704
# The Total No. of customers who visited stores on average over a month:  704,570

# %% [markdown]
# ### DATA PROFILING
# ### UNIVARIATE ANALYSIS

# %%
# The Decriptive Statistics of all the Numerical Columns

df.describe().astype(int)
# Out:
#        Store_ID  Store_Area  Items_Available  Daily_Customer_Count  \
# count       896         896              896                   896
# mean        448        1485             1782                   786
# std         258         250              299                   265
# min           1         775              932                    10
# 25%         224        1316             1575                   600
# 50%         448        1477             1773                   780
# 75%         672        1653             1982                   970
# max         896        2229             2667                  1560
#
#        Store_Sales
# count          896
# mean         59351
# std          17190
# min          14920
# 25%          46530
# 50%          58605
# 75%          71872
# max         116320

# %% [markdown]
# ### Key Insights and Summary
#
# **Store ID (Count, Mean, Min, Max):**
#
# - There are 896 unique store IDs in the dataset.
# - The mean store ID is 448, indicating that the dataset might encompass a large number of stores.
# - Store IDs range from 1 to 896, with no missing values.
#
# **Store Area (Mean, Standard Deviation, Quartiles):**
#
# - The average store area is approximately 1485 square units, with a standard deviation of 250.
# - Store areas vary considerably, with values ranging from 775 to 2229 square units.
# - The interquartile range (IQR) suggests that most stores fall within an area ranging from 1316 to 1653 square units.
#
# **Items Available (Mean, Standard Deviation, Quartiles):**
#
# - On average, there are around 1782 items available in each store, with a standard deviation of 299.
# - The range of items available spans from 932 to 2667.
# - The IQR indicates that the majority of stores have an item availability between 1575 and 1982.
#
# **Daily Customer Count (Mean, Standard Deviation, Quartiles):**
#
# - The mean daily customer count across all stores is approximately 786, with a standard deviation of 265.
# - Daily customer counts range from 10 to 1560.
# - The IQR suggests that most stores have a daily customer count ranging from 600 to 970.
#
# **Store Sales (Mean, Standard Deviation, Quartiles):**
#
# - The average daily store sales amount to 59351 units, with a standard deviation of 17190.
# - Daily store sales vary widely, with values ranging from 14920 to 116320 units.
# - The IQR indicates that the majority of stores have daily sales between 46530 and 71872 units.
#
# **Summary:**
#
# - The dataset comprises data from 896 stores.
# - Store characteristics such as store area and items available exhibit variability among stores, with some stores being larger and offering a wider range of products than others.
# - Daily customer counts and store sales also show variability across stores, suggesting differences in customer traffic and purchasing behavior.
# - An understanding of these variations can help identify high-performing stores, optimize inventory management, allocate resources efficiently, and formulate targeted strategies to improve overall performance and profitability across the supermarket chain.

# %%
### CORRELATION ANALYSIS

# %%
correlation_matrix = df.corr()
correlation_matrix
# Out:
#                       Store_ID  Store_Area  Items_Available  \
# Store_ID              1.000000   -0.058705        -0.055707
# Store_Area           -0.058705    1.000000         0.998891
# Items_Available      -0.055707    0.998891         1.000000
# Daily_Customer_Count -0.010029   -0.041423        -0.040978
# Store_Sales           0.071486    0.097474         0.098849
#
#                       Daily_Customer_Count  Store_Sales
# Store_ID                         -0.010029     0.071486
# Store_Area                       -0.041423     0.097474
# Items_Available                  -0.040978     0.098849
# Daily_Customer_Count              1.000000     0.008629
# Store_Sales                       0.008629     1.000000

# %%
# Create a heatmap using Seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)

# Add title
plt.title('Supermaket Store Branches Correlation Heatmap')

# Show the plot
plt.show()

# %% [markdown]
# ### Correlation Key Insights and Summary
#
# **Store ID Correlations:**
#
# - Store_ID has weak correlations with other variables, with coefficients close to zero for all variables.
# - This indicates that the store ID has little to no linear relationship with store area, items available, daily customer count, or store sales.
#
# **Store Area and Items Available Correlation:**
#
# - Store_Area and Items_Available exhibit a very strong positive correlation of approximately 0.998891.
# - This suggests that larger stores tend to have more items available for sale, which is intuitive as larger store areas can accommodate a greater variety of products.
#
# **Store Area and Store Sales Correlation:**
#
# - Store_Area and Store_Sales show a positive correlation of approximately 0.097474.
# - While this correlation is relatively weak, it indicates that larger stores may tend to have slightly higher sales volumes, although the relationship is not very strong.
#
# **Items Available and Store Sales Correlation:**
#
# - Items_Available and Store_Sales also exhibit a positive correlation of approximately 0.098849.
# - Similar to the correlation with store area, this suggests that stores with more items available may experience slightly higher sales volumes, although the correlation is not very strong.
#
# **Daily Customer Count Correlations:**
#
# - Daily_Customer_Count shows weak correlations with other variables, with coefficients close to zero for all variables.
# - This indicates that the daily customer count has little to no linear relationship with store area, items available, or store sales.
#
# **Summary:**
#
# - Store ID does not show significant correlations with other variables, indicating that it is likely an identifier without predictive value in this context.
# - There is a very strong positive correlation between store area and items available, suggesting that larger stores tend to offer more products.
# - Store area and items available exhibit weak positive correlations with store sales, indicating that larger stores or those with more items available may experience slightly higher sales volumes, although the relationships are not very strong.
# - Daily customer count does not show significant correlations with other variables, suggesting that factors other than store size or product availability may influence customer traffic.
# - These insights can inform decision-making processes related to store management, inventory planning, and sales strategies within the supermarket chain.

# %% [markdown]
# ### DATA VISUALIZATION

# %% [markdown]
# #### SCATTERPLOT TO SHOW DIFFERENT COMPARISONS IN THE STORES

# %%
# Scatterplot showing distributions between 'Store Area' and 'Store sales'
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Store_Area', y='Store_Sales', hue='Store_Sales', data=df,)
plt.title('Store Area vs. Store Sales')


# Scatterplot showing distributions between 'Daily Customer Count' and 'Store sales'
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Daily_Customer_Count', y='Store_Sales', hue= 'Store_Sales', data=df)
plt.title('Daily Customer Count vs. Store Sales')


# Scatterplot showing distributions between 'Store Area' and 'Daily Customer Count'
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Store_Area', y='Daily_Customer_Count', hue= 'Daily_Customer_Count', data=df)
plt.title('Store Area vs. Daily Customer Count')
# Out:
# Text(0.5, 1.0, 'Store Area vs. Daily Customer Count')

# %%
# Pairplot for all numerical variables
sns.pairplot(df[['Store_Area', 'Items_Available', 'Daily_Customer_Count', 'Store_Sales']])
plt.show()

# %% [markdown]
# #### OBSERVATION
#
# **Observation: Exploring Relationships in Store Dynamics**
#
# The series of scatterplots provides an insightful exploration of relationships among key variables in the dataset, shedding light on how 'Store Area,' 'Daily Customer Count,' and 'Store Sales' interact. Here are notable observations from each plot:
#
# **Store Area vs. Store Sales:**
#
# The first scatterplot visualizes the distribution between 'Store Area' and 'Store Sales.' It appears that as the 'Store Area' increases, there is a general trend of higher 'Store Sales.' The hues, represented by 'Store Sales,' indicate a positive correlation between these two variables. Larger store areas tend to be associated with increased sales, implying that stores with more extensive retail spaces may have the capacity to accommodate a more diverse inventory, potentially attracting a larger customer base.
#
# **Daily Customer Count vs. Store Sales:**
#
# The second scatterplot explores the relationship between 'Daily Customer Count' and 'Store Sales.' The hues, again representing 'Store Sales,' show a dispersed distribution. While there is no clear linear correlation, this suggests that the daily customer count alone might not be the sole determinant of overall store sales. Other factors may contribute to variations in sales, and further analysis is required to uncover additional insights.
#
# **Store Area vs. Daily Customer Count:**
#
#
# The third scatterplot illustrates the interplay between 'Store Area' and 'Daily Customer Count.' The hues, this time representing 'Daily Customer Count,' exhibit a scattered distribution. Interestingly, there is no clear pattern indicating that larger store areas directly correlate with higher daily customer counts. This could imply that factors beyond the physical size of the store may influence customer footfall.
# In conclusion, these scatterplots provide a visual narrative of the intricate dynamics within the dataset. While certain relationships are apparent, such as the positive correlation between 'Store Area' and 'Store Sales,' other associations are more nuanced. Further analysis, perhaps through statistical measures, would help uncover the underlying factors influencing these store dynamics.

# %% [markdown]
# #### HISTOGRAM SHOWING THE VARIOUS DISTRIBUTIONS WITHIN THE STORE

# %%
# A Histogram showing 'Store Sales Distribution'
sns.histplot(df['Store_Sales'], bins=20, color= '#0F491F', kde= True)
plt.title('Store Sales Distribution')
plt.xlabel('Store Sales')
plt.ylabel('Frequency')
plt.show()


# A Histogram showing 'Store Area Distribution'
sns.histplot(df['Store_Area'], bins=20, color= '#0F491F', kde= True)
plt.title('Store Area Distribution')
plt.xlabel('Store Area')
plt.ylabel('Frequency')
plt.show()


# A Histogram showing 'Daily Customer count Distribution'
sns.histplot(df['Daily_Customer_Count'],bins=20,color= '#0F491F', kde= True )
plt.title('Daily Customer Count Distribution')
plt.xlabel('Daily Customer count')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### OBSERVATION
#
# **Observation: Analyzing Store Metrics Through Seaborn Histograms**
#
# The Seaborn histograms provide a detailed visualization of the distribution of key metrics—'Store Sales,' 'Store Area,' and 'Daily Customer Count.' Let's explore the insights derived from each histogram:
#
# **Store Sales Distribution:**
#
# The first histogram showcases the distribution of 'Store Sales.' The use of Seaborn's histogram with kernel density estimation (kde) provides a smooth representation of the distribution. The data exhibits a right-skewed pattern, indicating that a majority of stores have moderate sales, while a smaller proportion achieves higher sales figures. The kernel density plot overlays additional insights, emphasizing the mode of the distribution and providing a continuous estimate of the probability density.
#
# **Store Area Distribution:**
#
# The second histogram focuses on the distribution of 'Store Area.' Similar to 'Store Sales,' the Seaborn histogram with kde reveals a relatively normal distribution of store sizes. Most stores in the dataset have a moderate-sized retail space, and there is a symmetric spread around the mean. The kernel density plot enhances our understanding of the density of store areas within the dataset.
#
# **Daily Customer Count Distribution:**
#
# The third histogram captures the distribution of 'Daily Customer Count.' The right-skewed pattern suggests that the majority of stores cater to a moderate number of daily customers, with a smaller proportion experiencing higher daily footfall. The inclusion of the kernel density plot accentuates the shape of the distribution, highlighting peaks and variations in customer counts.
# These Seaborn histograms not only provide a visual representation of the central tendencies and variabilities within each metric but also offer a more refined exploration through kernel density estimation. Further analysis, including statistical measures and potential correlations, would deepen our understanding of the relationships between these metrics and contribute to informed decision-making for store management and optimization.
#
#
# **Observation: Unveiling Patterns in Store Metrics**
#
# The series of histograms delves into the distributions of key metrics—'Store Sales,' 'Store Area,' and 'Daily Customer Count'—offering a glimpse into the underlying patterns within the dataset.
#
# **Store Sales Distribution:**
#
# The first histogram illustrates the distribution of 'Store Sales.' The data is right-skewed, with a majority of stores having moderate sales, and a few stores exhibiting higher sales. This skewed distribution suggests that a significant portion of stores falls within a certain sales range, while a smaller number of stores achieve notably higher sales figures. Understanding the characteristics of stores in the tail of the distribution could unveil insights into what sets them apart.
#
# **Store Area Distribution:**
#
# The second histogram explores the distribution of 'Store Area.' The data appears to be relatively normally distributed, indicating that the majority of stores have a moderate-sized retail space. There are fewer extremes in store area, suggesting that, in general, stores in the dataset share a common range of physical sizes. However, further analysis could reveal whether there is a correlation between store size and other variables, such as sales or customer count.
#
# **Daily Customer Count Distribution:**
#
#
# The third histogram presents the distribution of 'Daily Customer Count.' Similar to 'Store Sales,' this distribution is also right-skewed, indicating that a majority of stores cater to a moderate number of daily customers, while a smaller proportion of stores experiences higher daily footfall. This distribution prompts exploration into what factors contribute to higher daily customer counts and how they correlate with overall store success.
# In summary, these histograms serve as a preliminary exploration of the dataset, providing insights into the variability and tendencies within each metric. Further statistical analysis and correlation assessments between these metrics could uncover more nuanced relationships and assist in formulating actionable strategies for store management and optimization.

# %% [markdown]
# ### KEY PERFORMANCE INDICATORS (KPI)

# %%
# Total Value From Item Sales of Supermarket Store Branches
store_sales_sum = df['Store_Sales'].sum()
new_store_sales = '${:,.2f}'.format(store_sales_sum)
store_sales_sum
# Total Number of Store Branches
store_branches = df.Store_ID.nunique() - -1

# Total Number of Items Available In Stores
store_items = df['Items_Available'].sum()
new_store_items = '{:,.0f}'.format(store_items)

# Total Number of Daily Customers Across Store Branches
daily_customer_num = df['Daily_Customer_Count'].sum()
new_daily_customer_num = '{:,.0f}'.format(daily_customer_num)

# Total Size of All Store Branches
store_size = df['Store_Area'].sum()
new_store_size = '{:,.0f}'.format(store_size)


# Print Functions
print('Total Value From Item Sales of Supermarket Store Branches is: ', new_store_sales)
print('Total Number of Store Branches is: ', store_branches)
print('Total Number of Items Available In Stores is: ', new_store_items)
print('Total Number of Daily Customers Across Store Branches is: ', new_daily_customer_num)
print('Total Size of All Store Branches is: ', new_store_size)
# Out:
# Total Value From Item Sales of Supermarket Store Branches is:  $53,178,770.00
# Total Number of Store Branches is:  897
# Total Number of Items Available In Stores is:  1,596,704
# Total Number of Daily Customers Across Store Branches is:  704,570
# Total Size of All Store Branches is:  1,330,927

# %% [markdown]
# ### BIVARIATE ANALYSIS

# %%
# Bivariate
# The Top 10 Stores with the Most Items Sales
top10_stores = df.groupby('Store_ID')['Store_Sales'].sum().sort_values(ascending= False).head(10)
top10_stores
# Out:
# Store_ID
# 650    116320
# 869    105150
# 433    102920
# 409    102310
# 759    101820
# 558    101780
# 867    100900
# 167     99570
# 693     99480
# 872     98260
# Name: Store_Sales, dtype: int64

# %%
sns.set(style="white")  # Set the style for the plot

# Sort the DataFrame by 'Store_Sales' in descending order
top10_stores_sorted = top10_stores.sort_values(ascending=False)

custom_palette = sns.color_palette = ['#0F491F', '#0F4C57', '#017179', '#017E87', '#017E87', '#40E0D0', '#01F1F1', '#00FFFF', '#8CFFDB','#7FFFD4']
# Create a bar plot using Seaborn
plt.figure(figsize=(12, 6))
bar_plot = sns.barplot(x=top10_stores.index, y=top10_stores.values, palette=custom_palette, order=top10_stores_sorted.index)

# Add labels for the values on top of the bars with a $ sign
for p in bar_plot.patches:
    bar_plot.annotate(f'${format(p.get_height(), ",.0f")}',
                      (p.get_x() + p.get_width() / 2., p.get_height()),
                      ha='center', va='center',
                      xytext=(0, 9),
                      textcoords='offset points',
                      fontsize=10,
                      fontweight= 'bold',
                      color='black')

# Add labels and title
plt.xlabel('Store ID', fontsize= 12, fontweight= 'bold')
plt.ylabel('Store Sales', fontsize= 12, fontweight= 'bold')
plt.title('Top 10 Stores With The Most Item Sales', fontsize= 14, fontweight= 'bold')

# Show the plot
plt.show()

# %%
# Bivariate
# The Least 10 Stores with the Most Items Sales
least10_stores = df.groupby('Store_ID')['Store_Sales'].sum().sort_values(ascending= False).tail(10)
least10_stores
# Out:
# Store_ID
# 671    22310
# 253    21830
# 278    21750
# 373    21650
# 726    21470
# 353    21300
# 594    20270
# 776    17670
# 853    16370
# 32     14920
# Name: Store_Sales, dtype: int64

# %%
sns.set(style="white")  # Set the style for the plot

# Sort the DataFrame by 'Store_Sales' in descending order
least10_stores_sorted = least10_stores.sort_values(ascending=False)

# Create a bar plot using Seaborn
plt.figure(figsize=(12, 6))

custom_palette = sns.color_palette = ['#0F491F', '#0F4C57', '#017179', '#017E87', '#017E87', '#01F1F1', '#00FFFF', '#40E0D0', '#8CFFDB','#7FFFD4']

bar_plot = sns.barplot(x=least10_stores_sorted.index, y=least10_stores_sorted.values, palette=custom_palette, order=least10_stores_sorted.index)

# Add labels for the values on top of the bars with a $ sign
for p in bar_plot.patches:
    bar_plot.annotate(f'${format(p.get_height(), ",.0f")}',
                      (p.get_x() + p.get_width() / 2., p.get_height()),
                      ha='center', va='center',
                      xytext=(0, 9),
                      textcoords='offset points',
                      fontsize=10,
                      fontweight='bold',
                      color='black')

# Add labels and title
plt.xlabel('Store ID', fontsize=12, fontweight='bold')
plt.ylabel('Store Sales', fontsize=12, fontweight='bold')
plt.title('Least 10 Stores With Most Item Sales', fontsize=14, fontweight='bold')

# Show the plot
plt.show()

# %% [markdown]
# #### OBSERVATION
#
# **Top 10 Stores With Most Item Sales:**
#
# **Top Performers:** The stores listed in the "Top 10 Stores With Most Item Sales" represent the highest-performing branches based on sales. Store_ID 650 leads with sales of $116,320, indicating strong customer demand or effective sales strategies.
#
# **Consistent High Sales:** The presence of multiple stores with substantial sales suggests a consistent pattern of success across various branches. Identifying commonalities among these stores can guide strategies for other branches.
#
# **Revenue Concentration:** The top 10 stores significantly contribute to the overall revenue of the business. Strategies to maintain and enhance the performance of these stores can be crucial for sustained business success.
#
# **Least 10 Stores With Most Item Sales:**
#
# **Low Sales Impact:** The stores listed in the "Least 10 Stores With Most Item Sales" exhibit lower sales, with Store_ID 671 having the lowest sales at $22,310. These stores may face challenges that impact their sales performance.
#
# **Performance Disparities:** The lower sales in these stores highlight potential disparities in performance among different branches. Understanding the reasons behind the lower sales is crucial for making informed decisions.
#
# **Opportunities for Improvement:** The stores with lower sales present opportunities for improvement. Strategies such as targeted marketing, inventory adjustments, or operational enhancements may be considered to boost sales.
#
# **Resource Allocation Considerations:** Stakeholders may need to evaluate the allocation of resources, considering whether additional support, training, or marketing efforts are needed to improve the performance of these stores.
#
#
# In summary, analyzing the top and least-performing stores provides valuable insights into revenue distribution, opportunities for growth, and areas for improvement. These insights can guide strategic decisions to optimize overall store performance and maximize revenue.

# %%
# Stores details showing Store Area By Store Sales
df.groupby('Store_Area')['Store_Sales'].sum()
# Out:
# Store_Area
# 775     42530
# 780     25600
# 854     77740
# 869     52540
# 891     67370
#         ...
# 2063    51480
# 2067    70230
# 2169    67080
# 2214    65900
# 2229    87410
# Name: Store_Sales, Length: 583, dtype: int64

# %%
# Stores details showing Store Area and Daily Customer Count By Store Sales
df.groupby(['Store_Area', 'Daily_Customer_Count'])['Store_Sales'].sum()
# Out:
# Store_Area  Daily_Customer_Count
# 775         1090                    42530
# 780         790                     25600
# 854         660                     77740
# 869         850                     52540
# 891         630                     67370
#                                     ...
# 2063        810                     51480
# 2067        790                     70230
# 2169        600                     67080
# 2214        740                     65900
# 2229        660                     87410
# Name: Store_Sales, Length: 892, dtype: int64

# %%
# Multivariate
# The Top 10 Stores with the Most Items Sales By Store Area and Dily Customer Count
top10_stores = df.groupby(['Store_ID', 'Store_Area', 'Daily_Customer_Count'])['Store_Sales'].sum().sort_values(ascending= False).head(10)
top10_stores
# Out:
# Store_ID  Store_Area  Daily_Customer_Count
# 650       1989        860                     116320
# 869       1775        980                     105150
# 433       1365        680                     102920
# 409       1303        1310                    102310
# 759       1486        820                     101820
# 558       1137        700                     101780
# 867       1565        900                     100900
# 167       1465        680                      99570
# 693       1548        480                      99480
# 872       1800        1100                     98260
# Name: Store_Sales, dtype: int64

# %%
# Create a grouped bar plot for The Top 10 Stores with the Most Items Sales By Store Area and Daily Customer Count

# Extract necessary data for plotting
store_ids = top10_stores.index.get_level_values('Store_ID')
store_area = top10_stores.index.get_level_values('Store_Area')
daily_customer_counts = top10_stores.index.get_level_values('Daily_Customer_Count')
store_sales = top10_stores.values

# Set the figure size
plt.figure(figsize=(20, 8))  # Increase the figure size

# Increase the height of bars 2 and 3 by multiplying their values
height_factor_bars1 = 10  # You can adjust this factor
height_factor_bars3 = 10  # You can adjust this factor

# Plot grouped bar chart
bar_width = 0.30  # Increased width of each bar
index = range(len(store_ids))

bars2 = plt.bar([i + bar_width for i in index], store_sales, width=bar_width, color='#0F491F', label='Store Sales')
bars1 = plt.bar(index, store_area, width=bar_width, color='#00FFFF', label='Store Area')
bars3 = plt.bar([i + 2 * bar_width for i in index], daily_customer_counts, width=bar_width, color='red', label='Daily Customer Count')

# Set x-axis ticks and labels
plt.xticks([i + bar_width for i in index], store_ids)

# Add value labels on top of the bars
for bars in [bars1, bars2, bars3]:
    for bar in bars:
        yval = bar.get_height()
        if bars == bars2:  # Check if it's the 'Store Sales' bar
            plt.text(bar.get_x() + bar.get_width() / 2, yval, f'${yval:,.0f}', ha='center', va='bottom', fontsize=14, fontweight='bold')
        else:
            plt.text(bar.get_x() + bar.get_width() / 2, yval, round(yval, 2), ha='center', va='bottom', fontsize=14, fontweight='bold')

# Add labels and title
plt.xlabel('Store ID', fontsize=20)  # Increase the font size for x-axis label
plt.ylabel('Values', fontsize=20)  # Increase the font size for y-axis label
plt.title('Top 10 Stores with the Most Items Sales By Store Area, and Daily Customer Count', fontsize=25, fontweight='bold')  # Increase the font size for title

# Add legend
plt.legend(fontsize=13)  # Increase the font size for legend

# Show the plot
plt.show()

# %%
# Multivariate
# The Least 10 Stores with the Most Items Sales By Store Area and Dily Customer Count
least10_stores_sales = df.groupby(['Store_ID', 'Store_Area', 'Daily_Customer_Count'])['Store_Sales'].sum().sort_values(ascending= False).tail(10)
least10_stores_sales
# Out:
# Store_ID  Store_Area  Daily_Customer_Count
# 671       1461        1250                    22310
# 253       1583        680                     21830
# 278       1572        1030                    21750
# 373       1876        1340                    21650
# 726       1445        900                     21470
# 353       1397        850                     21300
# 594       1624        870                     20270
# 776       1537        660                     17670
# 853       1477        880                     16370
# 32        1250        990                     14920
# Name: Store_Sales, dtype: int64

# %%
# Create a grouped bar plot for The Least 10 Stores with the Most Items Sales By Store Area and Dily Customer Count

# Extract necessary data for plotting
store_ids = least10_stores_sales.index.get_level_values('Store_ID')
store_area = least10_stores_sales.index.get_level_values('Store_Area')
daily_customer_counts = least10_stores_sales.index.get_level_values('Daily_Customer_Count')
store_sales = least10_stores_sales.values

# Set the figure size
plt.figure(figsize=(20, 8))  # Increase the figure size

# Increase the height of bars 2 and 3 by multiplying their values
height_factor_bars1 = 5  # You can adjust this factor
height_factor_bars3 = 5  # You can adjust this factor

# Plot grouped bar chart
bar_width = 0.30  # Increased width of each bar
index = range(len(store_ids))


bars2 = plt.bar([i + bar_width for i in index], store_sales, width=bar_width, color='#0F491F', label='Store Sales')
bars1 = plt.bar(index, store_area, width=bar_width, color='#00FFFF', label='Store Area')
bars3 = plt.bar([i + 2 * bar_width for i in index], daily_customer_counts, width=bar_width, color='red', label='Daily Customer Count')

# Set x-axis ticks and labels
plt.xticks([i + bar_width for i in index], store_ids)

# Add value labels on top of the bars
for bars in [bars1, bars2, bars3]:
    for bar in bars:
        yval = bar.get_height()
        if bars == bars2:  # Check if it's the 'Store Sales' bar
            plt.text(bar.get_x() + bar.get_width() / 2, yval, f'${yval:,.0f}', ha='center', va='bottom', fontsize=14, fontweight='bold')
        else:
            plt.text(bar.get_x() + bar.get_width() / 2, yval, round(yval, 2), ha='center', va='bottom', fontsize=14, fontweight='bold')

# Add labels and title
plt.xlabel('Store ID', fontsize=20)  # Increase the font size for x-axis label
plt.ylabel('Values', fontsize=20)  # Increase the font size for y-axis label
plt.title('Least 10 Stores with the Most Items Sales By Store Area, and Daily Customer Count', fontsize=25, fontweight='bold')  # Increase the font size for title

# Add legend
plt.legend(fontsize=13)  # Increase the font size for legend

# Show the plot
plt.show()

# %% [markdown]
# #### OBSERVATION
#
# **Top 10 Stores with the Most Items Sales By Store Area, and Daily Customer Count:**
#
# **Store_ID 650:** This store has the highest Store_Sales of 116320, with a Store_Area of 1989 and a Daily_Customer_Count of 860. It demonstrates the effectiveness of the store in both attracting customers and driving sales.
#
# **Diverse Store Sizes:** The top-performing stores include a mix of store sizes, such as Store_ID 869 with Store_Area 1775 and Store_ID 433 with Store_Area 1365. This suggests that successful sales strategies can be implemented across various store sizes.
#
# **Balanced Customer Engagement:** While some stores have a higher Daily_Customer_Count, others maintain strong sales performance with a lower count, indicating effective strategies in engaging and converting customers.
#
# **Least 10 Stores with the Most Items Sales By Store Area, and Daily Customer Count:**
#
# **Challenges in Customer Attraction:** The least-performing stores face challenges in attracting a substantial daily customer count. Store_ID 253, for example, has a Daily_Customer_Count of 680, suggesting potential opportunities for improvement in customer engagement.
#
# **Store_ID 776:** Despite having a Store_Area of 1537, this store faces challenges with a relatively low Daily_Customer_Count of 660, reflecting potential areas for improvement in customer attraction and engagement.
#
# **Varied Store Sizes:** Similar to the top performers, the least-performing stores also exhibit diversity in store sizes. Store_ID 594 with Store_Area 1624 and Store_ID 853 with Store_Area 1477 represent different store sizes within the least-performing category.
#
# **Overall Insights:**
#
# **Balancing Store Size and Performance:** Both top and least-performing stores highlight the importance of balancing store size and customer engagement strategies to drive optimal sales performance.
#
# **Opportunities for Improvement:** The least-performing stores present opportunities for improvement in customer attraction and engagement, possibly through targeted marketing, promotions, or store layout enhancements.
#
# **Store_ID 650 Success Model:** Store_ID 650 serves as a potential model for success, demonstrating high sales performance despite variations in store size and daily customer count.
#
#
# In conclusion, analyzing store area, daily customer count, and item sales provides insights into the effectiveness of stores in engaging customers and generating sales. These insights can guide strategies to optimize performance and drive improvements in customer-centric retail environments.

# %%
# Multivariate
# The Top 10 Stores with the Most Daily Customer Count By Store Store Area and Store Sales
top10_daily_cust_count = df.groupby(['Store_ID', 'Store_Area' , 'Store_Sales'])['Daily_Customer_Count'].sum().sort_values(ascending= False).head(10)
top10_daily_cust_count
# Out:
# Store_ID  Store_Area  Store_Sales
# 849       919         73810          1560
# 350       1886        40350          1530
# 536       1057        35420          1490
# 95        1921        77120          1470
# 313       1494        43640          1450
# 17        1578        77250          1440
# 335       1624        44660          1440
# 232       1397        49160          1410
# 84        1572        42670          1410
# 649       1514        54820          1400
# Name: Daily_Customer_Count, dtype: int64

# %%
# Create a grouped bar plot for The Top 10 Stores with the Most Daily Customer Count By Store Store Area and Store Sales

# Extract necessary data for plotting
store_ids = top10_daily_cust_count.index.get_level_values('Store_ID')
store_area = top10_daily_cust_count.index.get_level_values('Store_Area')
store_sales = top10_daily_cust_count.index.get_level_values('Store_Sales')
daily_customer_count = top10_daily_cust_count.values

# Set the figure size
plt.figure(figsize=(20, 8))  # Increase the figure size

# Increase the height of bars 2 and 3 by multiplying their values
height_factor_bars1 = 10  # You can adjust this factor
height_factor_bars3 = 10  # You can adjust this factor

# Plot grouped bar chart
bar_width = 0.30  # Increased width of each bar
index = range(len(store_ids))



bars1 = plt.bar(index, daily_customer_count, width=bar_width, color='red', label='Daily Customer Count')
bars2 = plt.bar([i + 2 * bar_width for i in index], store_area, width=bar_width, color='#00FFFF', label='Store Area')
bars3 = plt.bar([i + bar_width for i in index],store_sales , width=bar_width, color='#0F491F', label='Store Sales')

# Set x-axis ticks and labels
plt.xticks([i + bar_width for i in index], store_ids)

# Add value labels on top of the bars
for bars in [bars1, bars2, bars3]:
    for bar in bars:
        yval = bar.get_height()
        if bars == bars3:  # Check if it's the 'Store Sales' bar
            plt.text(bar.get_x() + bar.get_width() / 2, yval, f'${yval:,.0f}', ha='center', va='bottom', fontsize=14, fontweight='bold')
        else:
            plt.text(bar.get_x() + bar.get_width() / 2, yval, round(yval, 2), ha='center', va='bottom', fontsize=14, fontweight='bold')

# Add labels and title
plt.xlabel('Store ID', fontsize=20)  # Increase the font size for x-axis label
plt.ylabel('Values', fontsize=20)  # Increase the font size for y-axis label
plt.title('Top 10 Stores with The Most Daily Customer Count By Store Area And Item Sales', fontsize=25, fontweight='bold')  # Increase the font size for title

# Add legend
plt.legend(fontsize=13)  # Increase the font size for legend

# Show the plot
plt.show()

# %%
# Bivariate
# The least 10 Stores with the Most Daily Customer Count By Store Store Area and Store Sales
least10_daily_cust_count = df.groupby(['Store_ID', 'Store_Area' , 'Store_Sales'])['Daily_Customer_Count'].sum().sort_values(ascending= False).tail(10)
least10_daily_cust_count
# Out:
# Store_ID  Store_Area  Store_Sales
# 539       1622        64780          210
# 2         1461        39820          210
# 711       1502        55980          190
# 827       1609        37920          160
# 888       1156        92370          140
# 147       1442        58920          130
# 231       1347        72350          120
# 877       1259        88270          100
# 152       1662        63730           70
# 40        1270        45480           10
# Name: Daily_Customer_Count, dtype: int64

# %%
# Create a grouped bar plot for The Least 10 Stores with the Most Daily Customer Count By Store Store Area and Store Sales


# Extract necessary data for plotting
store_ids = least10_daily_cust_count.index.get_level_values('Store_ID')
store_area = least10_daily_cust_count.index.get_level_values('Store_Area')
store_sales = least10_daily_cust_count.index.get_level_values('Store_Sales')
daily_customer_count = least10_daily_cust_count.values

# Set the figure size
plt.figure(figsize=(20, 8))  # Increase the figure size

# Increase the height of bars 2 and 3 by multiplying their values
height_factor_bars1 = 10  # You can adjust this factor
height_factor_bars3 = 10  # You can adjust this factor

# Plot grouped bar chart
bar_width = 0.30  # Increased width of each bar
index = range(len(store_ids))



bars1 = plt.bar(index, daily_customer_count, width=bar_width, color='red', label='Daily Customer Count')
bars2 = plt.bar([i + 2 * bar_width for i in index], store_area, width=bar_width, color='#00FFFF', label='Store Area')
bars3 = plt.bar([i + bar_width for i in index],store_sales , width=bar_width, color='#0F491F', label='Store Sales')

# Set x-axis ticks and labels
plt.xticks([i + bar_width for i in index], store_ids)

# Add value labels on top of the bars
for bars in [bars1, bars2, bars3]:
    for bar in bars:
        yval = bar.get_height()
        if bars == bars3:  # Check if it's the 'Store Sales' bar
            plt.text(bar.get_x() + bar.get_width() / 2, yval, f'${yval:,.0f}', ha='center', va='bottom', fontsize=14, fontweight='bold')
        else:
            plt.text(bar.get_x() + bar.get_width() / 2, yval, round(yval, 2), ha='center', va='bottom', fontsize=14, fontweight='bold')

# Add labels and title
plt.xlabel('Store ID', fontsize=20)  # Increase the font size for x-axis label
plt.ylabel('Values', fontsize=20)  # Increase the font size for y-axis label
plt.title('Least 10 Stores With The Most Daily Customer Count By Store Area and Item Sales', fontsize=25, fontweight='bold')  # Increase the font size for title

# Add legend
plt.legend(fontsize=13)  # Increase the font size for legend

# Show the plot
plt.show()

# %% [markdown]
# #### OBSERVATION
#
# **Top 10 Stores with The Most Daily Customer Count By Store Area And Item Sales:**
#
# **Store_ID 849:** This store, with a Store_Area of 919, leads the top performers with a high daily customer count of 1560 and significant Store_Sales of 73810. It demonstrates effective strategies in both customer engagement and sales.
#
# **Diverse Store Sizes:** The top-performing stores include a mix of store sizes, such as Store_ID 350 with Store_Area 1886 and Store_ID 536 with Store_Area 1057. This suggests that customer engagement strategies can be successful across various store sizes.
#
# **High Daily Customer Counts:** The top stores consistently attract a high daily customer count, ranging from 1400 to 1560. This indicates the effectiveness of these stores in drawing foot traffic.
#
# **Least 10 Stores With The Most Daily Customer Count By Store Area and Item Sales:**
#
# **Challenges in Customer Attraction:** The least-performing stores struggle to attract a substantial daily customer count. Store_ID 539 and Store_ID 2, for example, have a daily customer count of 210, indicating challenges in customer attraction strategies.
#
# **Store_ID 40:** This store faces significant challenges, with a Daily_Customer_Count of only 10, the lowest among the listed stores. Despite having a Store_Area of 1270, the sales performance is limited, suggesting potential opportunities for improvement.
#
# **Varied Store Sizes:** Similar to the top performers, the least-performing stores also exhibit diversity in store sizes. Store_ID 827 with Store_Area 1609 and Store_ID 888 with Store_Area 1156 represent different store sizes within the least-performing category.
#
# **Overall Insights:**
#
# **Importance of Daily Customer Count:** Both top and least-performing stores highlight the critical role of daily customer count in determining overall sales performance.
#
# **Store Size Impact:** While there is diversity in store sizes among both top and least performers, the impact of store size on customer engagement and sales needs further exploration.
#
# **Opportunities for Improvement:** The least-performing stores present opportunities for improvement in customer attraction and sales conversion strategies, possibly through targeted marketing or store layout enhancements.
#
#
# In conclusion, analyzing the daily customer count, store area, and item sales provides insights into the effectiveness of stores in engaging customers and generating sales. These insights can guide strategies to optimize performance and drive improvements in customer-centric retail environments.

# %%
# Multivariate
# The Top 10 Stores with the Most Stores Area By Store Sales and Daily Customer Count
top10_stores_area = df.groupby(['Store_ID', 'Daily_Customer_Count', 'Store_Sales'])['Store_Area'].sum().sort_values(ascending= False).head(10)
top10_stores_area
# Out:
# Store_ID  Daily_Customer_Count  Store_Sales
# 467       660                   87410          2229
# 541       740                   65900          2214
# 92        600                   67080          2169
# 850       790                   70230          2067
# 399       810                   51480          2063
# 551       720                   63510          2049
# 629       380                   82020          2044
# 164       340                   80340          2044
# 568       720                   51240          2026
# 312       540                   71570          2019
# Name: Store_Area, dtype: int64

# %%
# Create a grouped bar plot for The Top 10 Stores with the Most Store Area By Store Sales and Daily Customer Count

# Extract necessary data for plotting
store_ids = top10_stores_area.index.get_level_values('Store_ID')
daily_customer_count = top10_stores_area.index.get_level_values('Daily_Customer_Count')
store_sales = top10_stores_area.index.get_level_values('Store_Sales')
store_area = top10_stores_area.values

# Set the figure size
plt.figure(figsize=(20, 8))  # Increase the figure size

# Increase the height of bars 2 and 3 by multiplying their values
height_factor_bars1 = 10  # You can adjust this factor
height_factor_bars3 = 10  # You can adjust this factor

# Plot grouped bar chart
bar_width = 0.30  # Increased width of each bar
index = range(len(store_ids))



bars1 = plt.bar(index, store_area, width=bar_width, color='#00FFFF', label='Store Area')
bars2 = plt.bar([i + 2 * bar_width for i in index], daily_customer_count, width=bar_width, color='red', label='Daily Customer Count')
bars3 = plt.bar([i + bar_width for i in index],store_sales , width=bar_width, color='#0F491F', label='Store Sales')

# Set x-axis ticks and labels
plt.xticks([i + bar_width for i in index], store_ids)

# Add value labels on top of the bars
for bars in [bars1, bars2, bars3]:
    for bar in bars:
        yval = bar.get_height()
        if bars == bars3:  # Check if it's the 'Store Sales' bar
            plt.text(bar.get_x() + bar.get_width() / 2, yval, f'${yval:,.0f}', ha='center', va='bottom', fontsize=14, fontweight='bold')
        else:
            plt.text(bar.get_x() + bar.get_width() / 2, yval, round(yval, 2), ha='center', va='bottom', fontsize=14, fontweight='bold')

# Add labels and title
plt.xlabel('Store ID', fontsize=20)  # Increase the font size for x-axis label
plt.ylabel('Values', fontsize=20)  # Increase the font size for y-axis label
plt.title('Top 10 Stores With The Most Stores Area By Store Sales and Daily Customer Count', fontsize=25, fontweight='bold')  # Increase the font size for title

# Add legend
plt.legend(fontsize=13)  # Increase the font size for legend

# Show the plot
plt.show()

# %%
# Multivariate
# The Least 10 Stores with the Most Store Area By Store Sales and Daily Customer Count
least10_stores_area = df.groupby(['Store_ID', 'Daily_Customer_Count', 'Store_Sales'])['Store_Area'].sum().sort_values(ascending= False).tail(10)
least10_stores_area
# Out:
# Store_ID  Daily_Customer_Count  Store_Sales
# 849       1560                  73810          919
# 262       860                   56610          913
# 292       1210                  64640          902
# 498       680                   56820          902
# 407       870                   75110          896
# 73        630                   67370          891
# 550       850                   52540          869
# 745       660                   77740          854
# 866       790                   25600          780
# 159       1090                  42530          775
# Name: Store_Area, dtype: int64

# %%
# Create a grouped bar plot for The Least 10 Stores with the Most Store Area By Store Sales and Daily Customer Count

# Extract necessary data for plotting
store_ids = least10_stores_area.index.get_level_values('Store_ID')
daily_customer_count = least10_stores_area.index.get_level_values('Daily_Customer_Count')
store_sales = least10_stores_area.index.get_level_values('Store_Sales')
store_area = least10_stores_area.values

# Set the figure size
plt.figure(figsize=(20, 8))  # Increase the figure size

# Increase the height of bars 2 and 3 by multiplying their values
height_factor_bars1 = 10  # You can adjust this factor
height_factor_bars3 = 10  # You can adjust this factor

# Plot grouped bar chart
bar_width = 0.30  # Increased width of each bar
index = range(len(store_ids))



bars1 = plt.bar(index, store_area, width=bar_width, color='#00FFFF', label='Store Area')
bars2 = plt.bar([i + 2 * bar_width for i in index], daily_customer_count, width=bar_width, color='red', label='Daily Customer Count')
bars3 = plt.bar([i + bar_width for i in index],store_sales , width=bar_width, color='#0F491F', label='Store Sales')

# Set x-axis ticks and labels
plt.xticks([i + bar_width for i in index], store_ids)

# Add value labels on top of the bars
for bars in [bars1, bars2, bars3]:
    for bar in bars:
        yval = bar.get_height()
        if bars == bars3:  # Check if it's the 'Store Sales' bar
            plt.text(bar.get_x() + bar.get_width() / 2, yval, f'${yval:,.0f}', ha='center', va='bottom', fontsize=14, fontweight='bold')
        else:
            plt.text(bar.get_x() + bar.get_width() / 2, yval, round(yval, 2), ha='center', va='bottom', fontsize=14, fontweight='bold')

# Add labels and title
plt.xlabel('Store ID', fontsize=20)  # Increase the font size for x-axis label
plt.ylabel('Values', fontsize=20)  # Increase the font size for y-axis label
plt.title('Least 10 Stores With The Most Stores Area By Store Sales and Daily Customer Count', fontsize=25, fontweight='bold')  # Increase the font size for title

# Add legend
plt.legend(fontsize=13)  # Increase the font size for legend

# Show the plot
plt.show()

# %% [markdown]
# #### OBSERVATION
#
# **Top 10 Stores With The Most Store Area By Store Sales and Daily Customer Count:**
#
# **Store_ID 467:** This store has the largest Store_Area (2229) among the top performers. Despite a Daily_Customer_Count of 660, the high Store_Sales (87410) suggests efficient space utilization and effective sales strategies.
#
# **Diverse Store Sizes:** The top-performing stores exhibit diversity in Store_Area, with varying sizes ranging from Store_ID 850 with Store_Area 2067 to Store_ID 629 with Store_Area 2044. This diversity indicates successful strategies across different store sizes.
#
# **Store_ID 629:** Despite having a smaller Store_Area, Store_ID 629 achieves impressive Store_Sales (82020) with a relatively lower Daily_Customer_Count (380), indicating high sales efficiency.
#
# **Least 10 Stores With The Most Store Area By Store Sales and Daily Customer Count:**
#
# **Challenges in Sales Efficiency:** The least-performing stores, such as Store_ID 849 with Store_Area 919, face challenges in translating a large store size into high sales efficiency. Despite a significant Store_Area, the Store_Sales (73810) might indicate potential improvements in sales strategies.
#
# **Varied Store Sizes:** Similar to the top performers, the least-performing stores also demonstrate diversity in Store_Area, ranging from Store_ID 849 with Store_Area 919 to Store_ID 262 with Store_Area 913.
#
# **Store_ID 866:** This store has a relatively large Store_Area (780), but its Store_Sales (25600) and Daily_Customer_Count (790) suggest opportunities for optimizing sales efficiency and customer engagement.
#
# **Overall Insights:**
#
# **Efficiency vs. Size:** The analysis highlights that larger store areas do not always directly correlate with higher sales or customer counts. Efficient utilization of space and effective sales strategies play crucial roles.
#
# **Diversity in Success Models:** Both top and least-performing stores showcase diversity in store sizes, emphasizing the importance of tailored strategies based on individual store characteristics.
#
# **Opportunities for Improvement:** The least-performing stores present opportunities for improving sales efficiency, potentially through targeted marketing, store layout enhancements, or customer engagement strategies.
#
#
# In conclusion, analyzing store area, daily customer count, and item sales provides valuable insights into the efficiency and success of stores. These insights can guide strategies to optimize sales performance and enhance the overall customer experience within retail environments.
